# %%
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib notebook

# %%
cmd_frame = pd.read_pickle('cmd_frame_large_no_noise.pkl')

# %%
cmd_frame
# Out:
#          ageindex  metalindex  logage    logz      Mass       gmag       rmag  \
# 0             0.0         0.0    0.00  0.0000  0.000000  -0.000000  -0.000000
# 1             0.0         0.0    5.50 -3.6990  0.659148  -6.473236  -6.182609
# 2             0.0         0.0    5.50 -3.6990  0.103142 -14.305877 -12.006057
# 3             0.0         0.0    5.50 -3.6990  0.080055 -16.847125 -13.498070
# 4             0.0         0.0    5.50 -3.6990  0.554369  -7.332813  -6.929144
# 5             0.0         0.0    5.50 -3.6990  0.132854 -12.765739 -11.062171
# 6             0.0         0.0    5.50 -3.6990  0.188859 -10.416322  -9.585823
# 7             0.0         0.0    5.50 -3.6990  0.616840  -6.802819  -6.471154
# 8             0.0         0.0    5.50 -3.6990  0.172751 -10.652466  -9.792328
# 9             0.0         0.0    5.50 -3.6990  0.392382  -8.539514  -8.003943
# 10            0.0         0.0    5.50 -3.6990  0.197683 -10.286964  -9.472701
# ...

# %%
plt.plot(cmd_frame['grcolor'], cmd_frame['rmag'])
# Out:
# <img src="data:image/png;base64,..." width="640">
