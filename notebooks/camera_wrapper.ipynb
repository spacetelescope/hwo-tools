# %% [markdown]
# ## Illustration of the simple wrapper for camera_etc

# %% [markdown]
# First, import the wrapper function for obtaining HRI SNR from basic inputs

# %%
from syotools.wrappers.camera import camera_snr
import matplotlib.pyplot as plt

# %%
snr, hri = camera_snr('EAC1', 'flat', 31., 10.)
# Out:
# /Users/tumlinson/anaconda3/envs/hwotools/lib/python3.12/site-packages/pysynphot/locations.py:345: UserWarning: Extinction files not found in /Users/tumlinson/hwotools/hwo-tools/pysynphot_data/grp/redcat/trds/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))
# Warning, 5 of 20000 bins contained negative fluxes; they have been set to zero.
# /Users/tumlinson/anaconda3/envs/hwotools/lib/python3.12/site-packages/pysynphot/units.py:824: RuntimeWarning: divide by zero encountered in log
#   return -1.085736 * N.log(arg) + ABZERO
# Warning, 3590 of 20000 bins contained negative fluxes; they have been set to zero.
# Warning, 293 of 2920 bins contained negative fluxes; they have been set to zero.
# Setting Telescope to:  EAC1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 snr, hri = camera_snr('EAC1', 'flat', 31., 10.)
#
# File ~/hwotools/hwo-tools/syotools/wrappers/camera.py:16, in camera_snr(telescope, template, mag, exptime)
#      13 hri_exp = hri.create_exposure()
#      15 hri_exp.sed_id = template
# ---> 16 hri_exp.renorm_sed(mag * u.ABmag, bandpass='r')
#      17 exptime_list = []
#      18 for i in hri.bandnames: exptime_list.append(exptime)
#
# File ~/hwotools/hwo-tools/syotools/models/exposure.py:184, in Exposure.renorm_sed(self, new_mag, bandpass)
#     182 def renorm_sed(self, new_mag, bandpass='johnson,v'):
#     183     sed = self.recover('_sed')
# --> 184     self._sed = renorm_sed(sed, pre_decode(new_mag), bandpass=bandpass)
#     185     self.calculate()
#
# File ~/hwotools/hwo-tools/syotools/spectra/utils.py:23, in renorm_sed(sed, new_magnitude, bandpass)
#      19 def renorm_sed(sed, new_magnitude, bandpass='johnson,v'):
#      20     """
#      21     Utility to renormalize an SED to a new manitude.
#      22     """
# ---> 23     band = pys.ObsBandpass(bandpass)
#      24     band.convert(sed.waveunits)
#      26     new_sed = sed.renorm((new_magnitude + 2.5*u.mag('AB')).value, 'abmag', band)
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/pysynphot/obsbandpass.py:43, in ObsBandpass(obstring, graphtable, comptable, component_dict)
#      12 """Generate a bandpass object from observation mode.
#      13
#      14 If the bandpass consists of multiple throughput files
#    (...)
#      39
#      40 """
#      41 ##Temporarily create an Obsmode to determine whether an
#      42 ##ObsModeBandpass or a TabularSpectralElement will be returned.
# ---> 43 ob=ObservationMode(obstring,graphtable=graphtable,
#      44                    comptable=comptable,component_dict=component_dict)
#      45 if len(ob) > 1:
#      46     return ObsModeBandpass(ob)
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/pysynphot/observationmode.py:320, in ObservationMode.__init__(self, obsmode, method, graphtable, comptable, component_dict)
#     316 self.ctname = comptable
#     318 self._throughput_filenames = self._getFileNames(ct, self.compnames)
# --> 320 self.components = self._getOpticalComponents(self._throughput_filenames,
#     321                                               component_dict)
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/pysynphot/observationmode.py:335, in ObservationMode._getOpticalComponents(self, throughput_filenames, component_dict)
#     333   component = component_dict[(throughput_name, self.pardict.get(parkey))]
#     334 else:
# --> 335   component = _Component(throughput_name,
#     336                          interpval=self.pardict.get(parkey))
#     337   component_dict[(throughput_name, self.pardict.get(parkey))] = component
#     339 if not component.isEmpty():
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/pysynphot/observationmode.py:612, in _Component.__init__(self, throughput_name, interpval)
#     608 self.throughput_name = throughput_name
#     610 self._empty = True
# --> 612 self.throughput = self._buildThroughput(throughput_name, interpval)
#     613 if self.throughput is not None:
#     614     self.waveunits = self.throughput.waveunits
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/pysynphot/observationmode.py:623, in _Component._buildThroughput(self, name, interpval)
#     621 if interpval is None:
#     622     self._empty = False
# --> 623     return spectrum.TabularSpectralElement(name)
#     624 else:
#     625     self._empty = False
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/pysynphot/spectrum.py:2794, in TabularSpectralElement.__init__(self, fileName, thrucol)
#    2792 if fileName:
#    2793     if fileName.endswith('.fits') or fileName.endswith('.fit'):
# -> 2794         self._readFITS(fileName, thrucol)
#    2795     else:
#    2796         self._readASCII(fileName)
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/pysynphot/spectrum.py:2832, in TabularSpectralElement._readFITS(self, filename, thrucol)
#    2831 def _readFITS(self, filename, thrucol='throughput'):
# -> 2832     fs = pyfits.open(filename)
#    2834     # pyfits cannot close the file on .close() if there are still
#    2835     # references to mmapped data
#    2836     self._wavetable = fs[1].data.field('wavelength').copy()
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:222, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     219 if not name:
#     220     raise ValueError(f"Empty filename: {name!r}")
# --> 222 return HDUList.fromfile(
#     223     name,
#     224     mode,
#     225     memmap,
#     226     save_backup,
#     227     cache,
#     228     lazy_load_hdus,
#     229     ignore_missing_simple,
#     230     use_fsspec=use_fsspec,
#     231     fsspec_kwargs=fsspec_kwargs,
#     232     decompress_in_memory=decompress_in_memory,
#     233     **kwargs,
#     234 )
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:486, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     467 @classmethod
#     468 def fromfile(
#     469     cls,
#    (...)
#     477     **kwargs,
#     478 ):
#     479     """
#     480     Creates an `HDUList` instance from a file-like object.
#     481
#    (...)
#     484     documentation for details of the parameters accepted by this method).
#     485     """
# --> 486     return cls._readfrom(
#     487         fileobj=fileobj,
#     488         mode=mode,
#     489         memmap=memmap,
#     490         save_backup=save_backup,
#     491         cache=cache,
#     492         ignore_missing_simple=ignore_missing_simple,
#     493         lazy_load_hdus=lazy_load_hdus,
#     494         **kwargs,
#     495     )
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:1169, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#    1166 if fileobj is not None:
#    1167     if not isinstance(fileobj, _File):
#    1168         # instantiate a FITS file object (ffo)
# -> 1169         fileobj = _File(
#    1170             fileobj,
#    1171             mode=mode,
#    1172             memmap=memmap,
#    1173             cache=cache,
#    1174             use_fsspec=use_fsspec,
#    1175             fsspec_kwargs=fsspec_kwargs,
#    1176             decompress_in_memory=decompress_in_memory,
#    1177         )
#    1178     # The Astropy mode is determined by the _File initializer if the
#    1179     # supplied mode was None
#    1180     mode = fileobj.mode
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/astropy/io/fits/file.py:218, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     216     self._open_fileobj(fileobj, mode, overwrite)
#     217 elif isinstance(fileobj, (str, bytes)):
# --> 218     self._open_filename(fileobj, mode, overwrite)
#     219 else:
#     220     self._open_filelike(fileobj, mode, overwrite)
#
# File ~/anaconda3/envs/hwotools/lib/python3.12/site-packages/astropy/io/fits/file.py:641, in _File._open_filename(self, filename, mode, overwrite)
#     638 ext = os.path.splitext(self.name)[1]
#     640 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 641     self._file = open(self.name, IO_FITS_MODES[mode])
#     642     self.close_on_error = True
#     644 # Make certain we're back at the beginning of the file
#     645 # BZ2File does not support seek when the file is open for writing, but
#     646 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/tumlinson/hwotools/hwo-tools/pysynphot_data/grp/redcat/trds/comp/nonhst/cousins_r_004_syn.fits'
