# %%
# Import relevant modules 
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import rc
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=30, usetex=True)
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
mpl.rcParams['font.size'] = 15.0

# %%
import readsmart as rs

# %%
rs.atm('icrccm_62.atm', skiprows=11)

# %%
rs.rad('earth_standard_hitran08_50_100000cm-1_clearsky_toa.rad', plot=True, getdata=False)
# Out:
# readsmart/readsmart.py:145: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 98839 but corresponding boolean dimension is 7999
#   y = y[(x > xran[0]) & (x < xran[1])]
# /astro/users/jlustigy/.conda/envs/my_root/lib/python2.7/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
rs.rad('earth_standard_hitran08_50_100000cm-1_clearsky_toa.rad', plot=True, getdata=False, ptype='rad', xran=[1.0,15])
# Out:
# readsmart/readsmart.py:164: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 98839 but corresponding boolean dimension is 9333
#   y = y[(x > xran[0]) & (x < xran[1])]

# %%
rs.jacobians('earth_standard_hitran08_50_100000cm-1_clearsky_toa.rad', '.j_O3',\
             plot=True, getdata=False, xran=[3.0,5.0], pran=[100.,10000.])
# Out:
# Plotting 1333 of 99716 wavelength points (1%)

# %%
rs.hrt('earth_standard_hitran08_50_100000cm-1_clearsky.hrt', plot=True)
